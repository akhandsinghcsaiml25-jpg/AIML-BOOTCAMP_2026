# %% [markdown]
# <a href="https://colab.research.google.com/github/akhandsinghcsaiml25-jpg/AIML-BOOTCAMP_2026/blob/main/Session3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name="Akhand"
age=21
k=True
marks=92.5
print(name)
print(age)
print(k)
print(marks)
# Out:
# Akhand
# 21
# True
# 92.5

# %%
subject=["math","Bio","english","physics"]
print(subject[0])
print(subject[-1])
# Out:
# math
# physics

# %%
students = {
    "Sahaj": 85,
    "Anshul": 35,
    "Ansh": 72,
    "Amit": 38,
    "Lakshya": 50
}
for name, marks in students.items():
    if marks >= 40:
        print(f"{name}: Pass (Marks: {marks})")
    else:
        print(f"{name}: Fail (Marks: {marks})")
# Out:
# Sahaj: Pass (Marks: 85)
# Anshul: Fail (Marks: 35)
# Ansh: Pass (Marks: 72)
# Amit: Fail (Marks: 38)
# Lakshya: Pass (Marks: 50)

# %%
num = list(map(int,input("Enter a number").split()))
for i in num:
  if i> 0:
      print("positive")
  elif i < 0:
      print("negative")
  else:
      print("zero")

# %%
students= {
    "Akhand": {"study_hours": 5, "attendance": 80, "marks": 85},
    "Anshul":  {"study_hours": 3, "attendance": 70, "marks": 45},
    "Ansh":   {"study_hours": 6, "attendance": 90, "marks": 78},
    "Ashutosh":{"study_hours": 2, "attendance": 60, "marks": 15},
    "Sahaj":   {"study_hours": 4, "attendance": 76, "marks": 35}
}

name = input("Enter the student name: ")

if name in students:
    data = students[name]
    marks = data["marks"]
    attendance = data["attendance"]
    study_hours = data["study_hours"]

    print(f"{name}")

    if marks > 75:
        print("Performance: Strong")
    elif marks >= 40:
        print("Performance: Needs improvement")
    elif marks < 20:
        print("Performance: Fail, repeat class")
    else:
        print("Performance: Poor, requires immediate attention")

    if attendance < 75:
        print("Warning: Low attendance")

    if study_hours < 4:
        print("Advice: Needs more study time")

else:
    print("Error: Student not found in the directory.")

# %%
def calculate_pass(marks):
    if mark >= 27:
        return "Pass"
    else:
        return "Fail"


students = [20, 27, 35, 15, 40]

for mark in students:
    print(mark, "-", calculate_pass(mark))

# %%
# Student Starter Code
transactions = [
    {"transaction_id": "TX101", "amount": 6200, "method": "Credit Card"},
    {"transaction_id": "TX102", "amount": 5500, "method": "Gift Card"},
    {"transaction_id": "TX103", "amount": 1200, "method": "Gift Card"},
    {"transaction_id": "TX104", "amount": 8000, "method": "Gift Card"},
    {"transaction_id": "TX105", "amount": 450, "method": "PayPal"}
]

flagged_transactions = []



for i in transactions:
    if i["amount"] > 5000 and i["method"] == "Gift Card":
        flagged_transactions.append(i["transaction_id"])
print(flagged_transactions)

# %%
import numpy as np


marks = np.array([80, 75, 90, 65, 85, 70, 95, 60, 78, 88])


print(np.mean(marks))


print(np.max(marks))


print(np.min(marks))


print(np.sum(marks > 75))
