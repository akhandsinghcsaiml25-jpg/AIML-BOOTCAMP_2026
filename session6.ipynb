# %% [markdown]
# <a href="https://colab.research.google.com/github/akhandsinghcsaiml25-jpg/AIML-BOOTCAMP_2026/blob/main/session6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# classification- it mean are classifying an object
# regression- to predict a continous problem

# %%
#Face unlock-classification
#predicting land prices- Regression
#google photos use what to define faces- Classification
#weather forecast - Classification

#Student results(pass or fail)- Classification
#JEE MAINS marks or rank -Regression

#feature
'''percentile
score
rank
category
study hours per day
no of questions attempted
shifts
no students attempted
difficulty level of shift'''
